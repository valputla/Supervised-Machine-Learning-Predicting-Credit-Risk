# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
lending_data = pd.read_csv("/Users/lindseyvalput/Desktop/Supervised-Machine-Learning-Predicting-Credit-Risk/Resources/lending_data.csv")
lending_data.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0

# %%
# importing seaborn package
import seaborn
  
# Create a grid of column pairs with scatter plots for non-diagonal(upper portion)
seaborn.PairGrid(lending_data).map_upper(plt.scatter)
plt.show()

# %%
X = lending_data[['loan_size','interest_rate','borrower_income', 'debt_to_income', 'num_of_accounts', 'derogatory_marks', 'total_debt']]
y = lending_data['loan_status']

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (77536, 7) (77536,)

# %%
X_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(x_test, y_test)}")
# Out:
# Training Data Score: 0.9919177328380795
# Testing Data Score: 0.9924680148576145

# %%
# Split the data into X_train, X_test, y_train, y_test
# Out:
#        loan_size  interest_rate  borrower_income  debt_to_income  \
# 32815     8200.0          6.598            42700        0.297424
# 59572    10500.0          7.591            52000        0.423077
# 42325     7600.0          6.351            40400        0.257426
# 39070     9700.0          7.254            48900        0.386503
# 42524    11800.0          8.155            57300        0.476440
#
#        num_of_accounts  derogatory_marks  total_debt
# 32815                2                 0       12700
# 59572                4                 1       22000
# 42325                2                 0       10400
# 39070                4                 0       18900
# 42524                6                 1       27300

# %%
# Train a Logistic Regression model print the model score
# Out:
# 0.9908171687990095

# %%
# Train a Random Forest Classifier model and print the model score
# Out:
# 0.9910751134956666
